# %% [markdown]
# <a href="https://colab.research.google.com/github/Belashov641618/DNN/blob/main/collab/Incoherent2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Предварительная Настройка

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
import os
if os.path.abspath('.').endswith('DNN'):
  # %cd ..

# !rm -rf DNN/

# %%
# !git clone https://github.com/Belashov641618/DNN.git
# Out:
# Cloning into 'DNN'...
# remote: Enumerating objects: 722, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 722 (delta 30), reused 31 (delta 26), pack-reused 666
# Receiving objects: 100% (722/722), 36.34 MiB | 20.55 MiB/s, done.
# Resolving deltas: 100% (385/385), done.

# %%
# %cd DNN
import sys, os
sys.path.append(os.path.abspath('src'))
# Out:
# /content/DNN

# %%
# !pip install belashovplot
from belashovplot.belashovplot import DefaultFont, DefaultBigHeader, DefaultHeader, DefaultDefault, DefaultCaption, DefaultSmallCaption
DefaultFont['font'] = 'DejaVu Sans'
for Font in [DefaultBigHeader, DefaultHeader, DefaultDefault, DefaultCaption, DefaultSmallCaption]:
  Font.Font = 'DejaVu Sans'
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for belashovplot: filename=belashovplot-1.0-py3-none-any.whl size=12758 sha256=6e7041fe750f84abab3c61a9fb875877112737c3ca5db2e23079c681a6e6104a
#   Stored in directory: /root/.cache/pip/wheels/55/7b/e2/e5bf08c4c48d0989afbcb220497fa4bb6805a32f6c7826eece
# Successfully built belashovplot
# ...

# %%
import DNN.src as DNN
from DNN import utilities, modules
from modules import layers, wrappers, models
from utilities.Formaters import Format
from utilities.CycleTimePredictor import CycleTimePredictor
from utilities.UniversalTestsAndOther import GenerateSingleUnscaledSampleMNIST

# %%
import torch
import torchvision
from torchvision.transforms.functional import resize, pad
from torchvision.transforms import InterpolationMode
import numpy
import scipy
from itertools import product
from belashovplot import TiledPlot
import matplotlib.pyplot as plt

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Тестирование

# %%
from modules.wrappers.incoherent.noises.fouriers import gaussian, test_gaussian_3d, test_gaussian_2d

# %%
test_gaussian_2d(8, 256)

# %%
test_gaussian_3d(3, 3, 100, 30, 3.0)
# Out:
# 9it [00:01,  4.69it/s]
# 100%|██████████| 90/90 [01:19<00:00,  1.13it/s]

# %%
from IPython.display import Image
fname = 'test.gif'
Image(open(fname, 'rb').read())
